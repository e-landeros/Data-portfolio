# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import cufflinks as cf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
cf.go_offline()
init_notebook_mode(connected=True)
# import warnings
# warnings.filterwarnings('ignore')

# %matplotlib inline

#stock feed data is mostly deprecated in 2017 by yahoo, google and many others
#pandas-datareader is broken
#substitute historical pickle file for feed
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
bank_stocks =pd.read_pickle('all_banks')
#pickle file is python specific

# %%
#2006 data to 2015 data
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# ...

# %%
#cross section slice for multiindex dataframes
#get max close price from all bank stocks
#bank_stocks['BAC']['Close'].max()
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
# create empty dataframe to store the returns of bank stocks: price at date / prev date -1
returns = pd.DataFrame()
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %%
#first row of data has nothign to compare it to so it it NaN; start at index 1
sns.pairplot(returns[1:])

# %%
#november 2008 citigroup stock crash due to insolvency that is why returns are flat

# %%
#who had the best and worst single day return
#returns['BAC Return'] ; do this for every column or idx min to get the worst days
returns.idxmin()

#20th of january is obamas inaguration day
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
#citigroups best and worst return days close to eachother effective may 6th 2011; reverse stock split
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# # riskiest stock
# **looking for std deviation**

# %%
returns.std()
#citigroup had the most deviation for time period
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns.ix['2015-01-01':'2015-12-31'].std()
#when looking at different time period outside C rev split the standard deviations are very similar
#wfc marginally lowest risk; they were the best capitalized banks at the time
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.distplot(returns.ix['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=50)
#returns only deviate about .06 of average

# %%
sns.distplot(returns.ix['2008-01-01':'2008-12-31']['C Return'],color='red',bins=50)
# 2008 was a volatile year outlier up to .6

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,8))
plt.legend()

#bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()

# %%
bank_stocks.ix(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-172-3cb2d225f2d3> in <module>()
# ----> 1 bank_stocks.ix(key='Close',axis=1,level='Stock Info').iplot()
#
# TypeError: __call__() got an unexpected keyword argument 'key'

# %% [markdown]
# # rolling 30 day average against close of Bank of America

# %%
plt.figure(figsize=(12,6))
bank_stocks['BAC']['Close'].ix['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 day moving average')
bank_stocks['BAC']['Close'].ix['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %% [markdown]
# # Heatmap to show correlation between bank stocks

# %%
plt.figure(figsize=(12,8))
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
