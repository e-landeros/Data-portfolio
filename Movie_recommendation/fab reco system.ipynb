# %% [markdown]
# # This is a content based recommendation system using the movie lens data set.It is an item similarity based system.

# %%
import numpy as np
import pandas as pd

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']

# %%
df = pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df.tail()
# Out:
#         user_id  item_id  rating  timestamp
# 99998       880      476       3  880175444
# 99999       716      204       5  879795543
# 100000      276     1090       1  874795795
# 100001       13      225       2  882399156
# 100002       12      203       3  879959583

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 4 columns):
# user_id      100003 non-null int64
# item_id      100003 non-null int64
# rating       100003 non-null int64
# timestamp    100003 non-null int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %%
movie_titles = pd.read_csv('Movie_Id_Titles')

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df,movie_titles, on='item_id')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_context('notebook')
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head(20)
# Out:
# title
# Star Wars (1977)                    584
# Contact (1997)                      509
# Fargo (1996)                        508
# Return of the Jedi (1983)           507
# Liar Liar (1997)                    485
# English Patient, The (1996)         481
# Scream (1996)                       478
# Toy Story (1995)                    452
# Air Force One (1997)                431
# Independence Day (ID4) (1996)       429
# Raiders of the Lost Ark (1981)      420
# Godfather, The (1972)               413
# Pulp Fiction (1994)                 394
# Twelve Monkeys (1995)               392
# Silence of the Lambs, The (1991)    390
# Jerry Maguire (1996)                384
# Chasing Amy (1997)                  379
# Rock, The (1996)                    378
# Empire Strikes Back, The (1980)     368
# Star Trek: First Contact (1996)     365
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %% [markdown]
# ## As the data shows some movies have few reviews and very high ratings I will continue with visual exploratory data analysis to get a better understanding of the dataset.

# %%
ratings['num of ratings'] = df.groupby('title')['rating'].count()

# %%
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
ratings['num of ratings'].hist(bins=70);

# %%
ratings['rating'].hist(bins=70);

# %%
sns.jointplot(x='rating', y='num of ratings', data=ratings, alpha=0.5);
# Out:
# /Users/fabian/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/fabian/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
moviemat = df.pivot_table(index='user_id', columns='title', values='rating')

# %%
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
liarliar_user_ratings = moviemat['Liar Liar (1997)']

# %%
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
# Out:
# /Users/fabian/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/fabian/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# /Users/fabian/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/fabian/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)

# %%
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_starwars.sort_values('Correlation', ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Man of the Year (1995)                                      1.0
# Hollow Reed (1996)                                          1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Good Man in Africa, A (1994)                                1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])

# %%
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
# Sting, The (1973)                                      0.367538
# Indiana Jones and the Last Crusade (1989)              0.350107
# Pinocchio (1940)                                       0.347868
# Frighteners, The (1996)                                0.332729
# L.A. Confidential (1997)                               0.319065
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# ...

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar, columns=['Correlation'])

# %%
corr_liarliar.dropna(inplace=True)

# %%
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])

# %%
corr_liarliar[corr_liarliar['num of ratings']>90].sort_values('Correlation', ascending=False)
# Out:
#                                                     Correlation  \
# title
# Liar Liar (1997)                                       1.000000
# Batman Forever (1995)                                  0.516968
# Bean (1997)                                            0.504689
# Mask, The (1994)                                       0.484650
# Down Periscope (1996)                                  0.472681
# Con Air (1997)                                         0.469828
# Pretty Woman (1990)                                    0.469790
# 101 Dalmatians (1996)                                  0.469765
# Demolition Man (1993)                                  0.442948
# Michael (1996)                                         0.442022
# Waterworld (1995)                                      0.438405
# So I Married an Axe Murderer (1993)                    0.434577
# Space Jam (1996)                                       0.429766
# ...
